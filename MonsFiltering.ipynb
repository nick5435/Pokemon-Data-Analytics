# %%
import sqlite3
import numpy as np
import pandas as pd
import scipy.stats as stats
import scipy as sci
import matplotlib.pyplot as plt
import sklearn as skl
import statsmodels.api as sma
import statsmodels as sm
import statsmodels.formula.api as smf
from sklearn import decomposition
import statsmodels.stats.multicomp as comp
import seaborn as sns

# %matplotlib inline
# Out:
# C:\Anaconda3\lib\site-packages\statsmodels\compat\pandas.py:56: FutureWarning: The pandas.core.datetools module is deprecated and will be removed in a future version. Please use the pandas.tseries module instead.
#   from pandas.core import datetools

# %%
mons = pd.read_csv("../Datasets/pokemon_preUSUM_data_with_total.csv")

# %%
mons.head(2)
# Out:
#    DEXID       NAME  HP  ATTACK  DEFENSE  SPECIAL_ATTACK  SPECIAL_DEFENSE  \
# 0      1  BULBASAUR  45      49       49              65               65
# 1      2    IVYSAUR  60      62       63              80               80
#
#    SPEED  STAT_TOTAL  GEN
# 0     45         318    1
# 1     60         405    1

# %%
filtered = mons.sort_values("STAT_TOTAL", ascending=False).drop_duplicates("DEXID").sort_index()

# %%
filtered.shape
# Out:
# (802, 10)

# %%
mons.shape
# Out:
# (1025, 10)

# %%
filtered.to_csv("../Datasets/pokemon_stats_maxbyID.csv")

# %%
filtered = mons[~mons["NAME"].str.contains("-MEGA") & 
                ~mons["NAME"].str.contains("PRIMAL") &
               ~mons["NAME"].str.contains("ALOLA")].sort_values("STAT_TOTAL", ascending=False).drop_duplicates("DEXID").sort_values("DEXID", ascending=True)

# %%
filtered.head(100)
# Out:
#      DEXID        NAME   HP  ATTACK  DEFENSE  SPECIAL_ATTACK  SPECIAL_DEFENSE  \
# 0        1   BULBASAUR   45      49       49              65               65
# 1        2     IVYSAUR   60      62       63              80               80
# 2        3    VENUSAUR   80      82       83             100              100
# 3        4  CHARMANDER   39      52       43              60               50
# 4        5  CHARMELEON   58      64       58              80               65
# 5        6   CHARIZARD   78      84       78             109               85
# 6        7    SQUIRTLE   44      48       65              50               64
# 7        8   WARTORTLE   59      63       80              65               80
# 8        9   BLASTOISE   79      83      100              85              105
# 9       10    CATERPIE   45      30       35              20               20
# 10      11     METAPOD   50      20       55              25               25
# 11      12  BUTTERFREE   60      45       50              90               80
# 12      13      WEEDLE   40      35       30              20               20
# 13      14      KAKUNA   45      25       50              25               25
# 14      15    BEEDRILL   65      90       40              45               80
# 15      16      PIDGEY   40      45       40              35               35
# 16      17   PIDGEOTTO   63      60       55              50               50
# 17      18     PIDGEOT   83      80       75              70               70
# 18      19     RATTATA   30      56       35              25               35
# 810     20  RATICATE-1   75      71       70              40               80
# 20      21     SPEAROW   40      60       30              31               31
# 21      22      FEAROW   65      90       65              61               61
# 22      23       EKANS   35      60       44              40               54
# 23      24       ARBOK   60      95       69              65               79
# 24      25     PIKACHU   35      55       40              50               50
# 25      26      RAICHU   60      90       55              90               80
# 26      27   SANDSHREW   50      75       85              20               30
# 27      28   SANDSLASH   75     100      110              45               55
# 28      29   NIDORAN-F   55      47       52              40               40
# 29      30    NIDORINA   70      62       67              55               55
# ..     ...         ...  ...     ...      ...             ...              ...
# 70      71  VICTREEBEL   80     105       65             100               70
# 71      72   TENTACOOL   40      40       35              50              100
# 72      73  TENTACRUEL   80      70       65              80              120
# 73      74     GEODUDE   40      80      100              30               30
# 74      75    GRAVELER   55      95      115              45               45
# 75      76       GOLEM   80     120      130              55               65
# 76      77      PONYTA   50      85       55              65               65
# 77      78    RAPIDASH   65     100       70              80               80
# 78      79    SLOWPOKE   90      65       65              40               40
# 79      80     SLOWBRO   95      75      110             100               80
# 80      81   MAGNEMITE   25      35       70              95               55
# 81      82    MAGNETON   50      60       95             120               70
# 82      83  FARFETCH�D   52      90       55              58               62
# 83      84       DODUO   35      85       45              35               35
# 84      85      DODRIO   60     110       70              60               60
# 85      86        SEEL   65      45       55              45               70
# 86      87     DEWGONG   90      70       80              70               95
# 87      88      GRIMER   80      80       50              40               50
# 88      89         MUK  105     105       75              65              100
# 89      90    SHELLDER   30      65      100              45               25
# 90      91    CLOYSTER   50      95      180              85               45
# 91      92      GASTLY   30      35       30             100               35
# 92      93     HAUNTER   45      50       45             115               55
# 93      94      GENGAR   60      65       60             130               75
# 94      95        ONIX   35      45      160              30               45
# 95      96     DROWZEE   60      48       45              43               90
# 96      97       HYPNO   85      73       70              73              115
# 97      98      KRABBY   30     105       90              25               25
# 98      99     KINGLER   55     130      115              50               50
# 99     100     VOLTORB   40      30       50              55               55
#
#      SPEED  STAT_TOTAL  GEN
# 0       45         318    1
# 1       60         405    1
# 2       80         525    1
# 3       65         309    1
# 4       80         405    1
# 5      100         534    1
# 6       43         314    1
# 7       58         405    1
# 8       78         530    1
# 9       45         195    1
# 10      30         205    1
# 11      70         395    1
# 12      50         195    1
# 13      35         205    1
# 14      75         395    1
# 15      56         251    1
# 16      71         349    1
# 17     101         479    1
# 18      72         253    1
# 810     77         413    1
# 20      70         262    1
# 21     100         442    1
# 22      55         288    1
# 23      80         448    1
# 24      90         320    1
# 25     110         485    1
# 26      40         300    1
# 27      65         450    1
# 28      41         275    1
# 29      56         365    1
# ..     ...         ...  ...
# 70      70         490    1
# 71      70         335    1
# 72     100         515    1
# 73      20         300    1
# 74      35         390    1
# 75      45         495    1
# 76      90         410    1
# 77     105         500    1
# 78      15         315    1
# 79      30         490    1
# 80      45         325    1
# 81      70         465    1
# 82      60         377    1
# 83      75         310    1
# 84     100         460    1
# 85      45         325    1
# 86      70         475    1
# 87      25         325    1
# 88      50         500    1
# 89      40         305    1
# 90      70         525    1
# 91      80         310    1
# 92      95         405    1
# 93     110         500    1
# 94      70         385    1
# 95      42         328    1
# 96      67         483    1
# 97      50         325    1
# 98      75         475    1
# 99     100         330    1
#
# [100 rows x 10 columns]

# %%
filtered.to_csv("../Datasets/pokemon_nomegas_byid.csv")
